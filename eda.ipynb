# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/feature_enginering.csv')

# %%
df.head()
# Out:
#   person_gender person_education  person_income person_home_ownership  \
# 0        Female           Master        71948.0                  Rent
# 1        Female      High School        28367.0                   Own
# 2        Female      High School        28367.0              Mortgage
# 3        Female         Bachelor        79753.0                  Rent
# 4          Male           Master        66135.0                  Rent
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    19200.0    Personal          16.00                 0.31
# 1     3000.0   Education          11.14                 0.08
# 2     5500.0     Medical          12.87                 0.31
# 3    19200.0     Medical          15.23                 0.31
# 4    19200.0     Medical          14.27                 0.31
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           539                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#    loan_status  net_disposable_income
# 0            1               68876.00
# 1            0               28032.80
# 2            1               27659.15
# 3            1               76828.84
# 4            1               63395.16

# %%
df['loan_status'].replace([1, 0], ['Approved', 'Rejected'], inplace=True)

# %%
df.head()
# Out:
#   person_gender person_education  person_income person_home_ownership  \
# 0        Female           Master        71948.0                  Rent
# 1        Female      High School        28367.0                   Own
# 2        Female      High School        28367.0              Mortgage
# 3        Female         Bachelor        79753.0                  Rent
# 4          Male           Master        66135.0                  Rent
#
#    loan_amnt loan_intent  loan_int_rate  loan_percent_income  \
# 0    19200.0    Personal          16.00                 0.31
# 1     3000.0   Education          11.14                 0.08
# 2     5500.0     Medical          12.87                 0.31
# 3    19200.0     Medical          15.23                 0.31
# 4    19200.0     Medical          14.27                 0.31
#
#    cb_person_cred_hist_length  credit_score previous_loan_defaults_on_file  \
# 0                         3.0           561                             No
# 1                         2.0           539                            Yes
# 2                         3.0           635                             No
# 3                         2.0           675                             No
# 4                         4.0           586                             No
#
#   loan_status  net_disposable_income
# 0    Approved               68876.00
# 1    Rejected               28032.80
# 2    Approved               27659.15
# 3    Approved               76828.84
# 4    Approved               63395.16

# %%
sns.countplot(x='person_gender', data=df, hue='loan_status', palette=['#e74c3c', '#2ecc71'])
plt.title('Loan Status According to Gender')
plt.savefig('charts/loan_status_gender.png')
plt.show()

# %%
sns.countplot(x='person_education', data=df, hue='loan_status', palette=['#e74c3c', '#2ecc71'])
plt.title('Loan Status According to Education Qualification')
plt.savefig('charts/loan_status_education.png')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='loan_intent', data=df, hue='loan_status', palette=['#e74c3c', '#2ecc71'])
plt.title('Loan Status According to Loan Intent')
plt.savefig('charts/loan_status_intent.png')
plt.show()

# %%
sns.displot(df['person_income'], kde=True)
plt.title('Income')
plt.savefig('charts/income_range.png')
plt.ticklabel_format(style='plain', axis='x')

# %%
sns.displot(df['loan_amnt'], kde=True)
plt.title('Loan Amount')
plt.savefig('charts/loan_range.png')
plt.ticklabel_format(style='plain', axis='x')

# %%
sns.displot(df['credit_score'], kde=True)
plt.title('Credit Score')
plt.savefig('charts/credit_range.png')
plt.show()

# %%
sns.scatterplot(x='person_income', y='loan_amnt', data=df, hue='loan_status', palette=['#2ecc71', '#e74c3c'])
plt.title('Income vs Loan Amount')
plt.savefig('charts/income_vs_loan.png')
plt.ticklabel_format(style='plain', axis='x')
